# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy.stats import norm
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
USpolice = pd.read_excel("New/USDATA/KnownUSincedents/Table_8_Offenses_Known_to_Law_Enforcement_by_State_by_City_2021.xlsx")

# %%
USpolice.head()
# Out:
#                              Table 8 Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0  Offenses Known to Law Enforcement        NaN         NaN             NaN
# 1             by State by City, 2021        NaN         NaN             NaN
# 2                              State       City  Population  Violent\ncrime
# 3                            ALABAMA  Abbeville        2539               4
# 4                                NaN  Alabaster       33963              25
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                     NaN        NaN        NaN
# 1                                     NaN        NaN        NaN
# 2  Murder and\nnonnegligent\nmanslaughter       Rape    Robbery
# 3                                       1          0          0
# 4                                       1          4          0
#
#             Unnamed: 7       Unnamed: 8 Unnamed: 9      Unnamed: 10  \
# 0                  NaN              NaN        NaN              NaN
# 1                  NaN              NaN        NaN              NaN
# 2  Aggravated\nassault  Property\ncrime   Burglary  Larceny-\ntheft
# 3                    3               53         11               37
# 4                   20              282         13              253
#
#              Unnamed: 11 Unnamed: 12
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2  Motor\nvehicle\ntheft       Arson
# 3                      5           0
# 4                     16           1

# %%
USpolice.drop([0,1,2,5878],inplace=True)

# %%
USpolice.rename(columns={"Table 8":"State","Unnamed: 1":"City","Unnamed: 2":"Population","Unnamed: 3":"ViolentCrime","Unnamed: 4":"MurderNonnegligentManslaughter",
"Unnamed: 5":"Rape","Unnamed: 6":"Robbery","Unnamed: 7":"AggravatedAssault","Unnamed: 8":"PropertyCrime","Unnamed: 9":"Burglary","Unnamed: 10":"Larcenytheft","Unnamed: 11":"Motor\nvehicle\ntheft","Unnamed: 12":"Arson"},inplace=True)

# %%
USpolice
# Out:
#         State            City Population ViolentCrime  \
# 3     ALABAMA       Abbeville       2539            4
# 4         NaN       Alabaster      33963           25
# 5         NaN  Alexander City      14066           40
# 6         NaN         Altoona        913            4
# 7         NaN       Andalusia       8643           44
# ...       ...             ...        ...          ...
# 5873      NaN    Rock Springs      22937           49
# 5874      NaN        Sheridan      18157           15
# 5875      NaN     Thermopolis       2747            2
# 5876      NaN      Torrington       6564           16
# 5877      NaN         Worland       4947            5
#
#      MurderNonnegligentManslaughter Rape Robbery AggravatedAssault  \
# 3                                 1    0       0                 3
# 4                                 1    4       0                20
# 5                                 0    0       7                33
# 6                                 0    0       0                 4
# 7                                 1    6       1                36
# ...                             ...  ...     ...               ...
# 5873                              1   17       2                29
# 5874                              0    0       0                15
# 5875                              0    0       0                 2
# 5876                              1    4       0                11
# 5877                              0    2       0                 3
#
#      PropertyCrime Burglary Larcenytheft Motor\nvehicle\ntheft Arson
# 3               53       11           37                     5     0
# 4              282       13          253                    16     1
# 5              283      178           87                    18     1
# 6                7        1            6                     0     0
# 7              254       45          198                    11     0
# ...            ...      ...          ...                   ...   ...
# 5873           286       44          217                    25     3
# 5874           239       19          202                    18     2
# 5875            25        2           23                     0     0
# 5876            63       15           40                     8     1
# 5877            37        0           34                     3     1
#
# [5875 rows x 13 columns]

# %%
USpoliceage = pd.read_csv("New/USDATA/ucrAgeGender.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1083, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1233, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1246, in pandas._libs.parsers.TextReader._string_convert()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1444, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 106: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 USpoliceage = pd.read_csv("New/USDATA/ucrAgeGender.csv")
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\Python3\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File C:\Python3\lib\site-packages\pandas\io\parsers\readers.py:1772, in TextFileReader.read(self, nrows)
#    1765 nrows = validate_integer("nrows", nrows)
#    1766 try:
#    1767     # error: "ParserBase" has no attribute "read"
#    1768     (
#    1769         index,
#    1770         columns,
#    1771         col_dict,
# -> 1772     ) = self._engine.read(  # type: ignore[attr-defined]
#    1773         nrows
#    1774     )
#    1775 except Exception:
#    1776     self.close()
#
# File C:\Python3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:243, in CParserWrapper.read(self, nrows)
#     241 try:
#     242     if self.low_memory:
# --> 243         chunks = self._reader.read_low_memory(nrows)
#     244         # destructive to chunks
#     245         data = _concatenate_chunks(chunks)
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:890, in pandas._libs.parsers.TextReader._read_rows()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1037, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1090, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1233, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1246, in pandas._libs.parsers.TextReader._string_convert()
#
# File C:\Python3\lib\site-packages\pandas\_libs\parsers.pyx:1444, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 106: invalid start byte
