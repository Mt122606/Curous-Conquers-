# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy.stats import norm
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
UKemploy = pd.read_excel("New/UKDATA/a02sajan2023.xls")

# %%
len(UKemploy)
# Out:
# 2

# %%
UKemploy.keys
# Out:
# <bound method NDFrame.keys of                                      IMPORTANT NOTE:
# 0                                                NaN
# 1  The population totals used for the latest LFS ...>

# %%
UKemploy.head()
# Out:
#                                      IMPORTANT NOTE:
# 0                                                NaN
# 1  The population totals used for the latest LFS ...

# %%
UKemploy = pd.ExcelFile('New/UKDATA/a02sajan2023.xls')
UKsheet1 = UKemploy.parse(1)

# %%
UKsheet1
# Out:
#     Table A02:  Labour Force Survey Summary:  People by economic activity for those aged 16 and over and those aged from 16 to 64 (seasonally adjusted)  \
# 0                                 Date of publication:
# 1                                   Inquiries: Email:
# 2       United Kingdom (thousands) seasonally adjusted
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 643                                                NaN
# 644  Note on headline employment, unemployment and ...
# 645  The headline employment and unemployment level...
# 646  However, the headline inactivity level is for ...
# 647  people who have retired from the labour force....
#
#              Unnamed: 1                 Unnamed: 2                 Unnamed: 3  \
# 0                   NaN        2023-01-17 00:00:00                        NaN
# 1                   NaN                        NaN  labour.market@ons.gov.uk
# 2                   NaN                        NaN                        NaN
# 3    All aged 16 & over                        NaN                        NaN
# 4    All aged 16 & over  Total economically active        Total in employment
# ..                  ...                        ...                        ...
# 643                 NaN                        NaN                        NaN
# 644                 NaN                        NaN                        NaN
# 645                 NaN                        NaN                        NaN
# 646                 NaN                        NaN                        NaN
# 647                 NaN                        NaN                        NaN
#
#      Unnamed: 4             Unnamed: 5                 Unnamed: 6  Unnamed: 7  \
# 0           NaN                    NaN  Date of next publication:         NaN
# 1           NaN                    NaN                 Telephone:         NaN
# 2           NaN                    NaN                        NaN         NaN
# 3           NaN                    NaN                        NaN         NaN
# 4    Unemployed  Economically inactive          Economic activity  Employment
# ..          ...                    ...                        ...         ...
# 643         NaN                    NaN                        NaN         NaN
# 644         NaN                    NaN                        NaN         NaN
# 645         NaN                    NaN                        NaN         NaN
# 646         NaN                    NaN                        NaN         NaN
# 647         NaN                    NaN                        NaN         NaN
#
#               Unnamed: 8           Unnamed: 9        Unnamed: 10  \
# 0    2023-02-14 00:00:00                  NaN                NaN
# 1                    NaN   +44 (0)1633 455400                NaN
# 2                    NaN                  NaN                NaN
# 3                    NaN                  NaN  All aged 16 to 64
# 4           Unemployment  Economic inactivity  All aged 16 to 64
# ..                   ...                  ...                ...
# 643                  NaN                  NaN                NaN
# 644                  NaN                  NaN                NaN
# 645                  NaN                  NaN                NaN
# 646                  NaN                  NaN                NaN
# 647                  NaN                  NaN                NaN
#
#                     Unnamed: 11          Unnamed: 12 Unnamed: 13  \
# 0                           NaN                  NaN         NaN
# 1                           NaN                  NaN         NaN
# 2                           NaN                  NaN         NaN
# 3                           NaN                  NaN         NaN
# 4    Total economically active   Total in employment  Unemployed
# ..                          ...                  ...         ...
# 643                         NaN                  NaN         NaN
# 644                         NaN                  NaN         NaN
# 645                         NaN                  NaN         NaN
# 646                         NaN                  NaN         NaN
# 647                         NaN                  NaN         NaN
#
#                Unnamed: 14        Unnamed: 15 Unnamed: 16   Unnamed: 17  \
# 0                      NaN                NaN         NaN           NaN
# 1                      NaN                NaN    Source:            NaN
# 2                      NaN                NaN         NaN           NaN
# 3                      NaN                NaN         NaN           NaN
# 4    Economically inactive  Economic activity  Employment  Unemployment
# ..                     ...                ...         ...           ...
# 643                    NaN                NaN         NaN           NaN
# 644                    NaN                NaN         NaN           NaN
# 645                    NaN                NaN         NaN           NaN
# 646                    NaN                NaN         NaN           NaN
# 647                    NaN                NaN         NaN           NaN
#
#              Unnamed: 18
# 0                    NaN
# 1    Labour Force Survey
# 2                    NaN
# 3                    NaN
# 4    Economic inactivity
# ..                   ...
# 643                  NaN
# 644                  NaN
# 645                  NaN
# 646                  NaN
# 647                  NaN
#
# [648 rows x 19 columns]
