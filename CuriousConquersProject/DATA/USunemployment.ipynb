# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from scipy.stats import norm
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
USunemploy = pd.read_csv("New/USDATA/unemployment_rate_data.csv")

# %% [markdown]
# ### Contains the monthly unemployment rate from 1948-2021. This file also contains information on subsets of the population, including based on age ranges from 16-55 and over, and unemployment rates for men and women. This data is collected by the US Bureau of Labor Statistics.

# %%
USunemploy.tail(12)
# Out:
#           date  unrate  unrate_men  unrate_women  unrate_16_to_17  \
# 875  12/1/2020     6.5         6.7           6.3             11.8
# 876   1/1/2021     6.8         7.1           6.5             15.2
# 877   2/1/2021     6.6         7.0           6.1             14.5
# 878   3/1/2021     6.2         6.5           5.8             12.0
# 879   4/1/2021     5.7         6.0           5.4             10.5
# 880   5/1/2021     5.5         5.7           5.2              9.2
# 881   6/1/2021     6.1         6.1           6.1             15.0
# 882   7/1/2021     5.7         5.5           5.8             12.8
# 883   8/1/2021     5.3         5.1           5.5             10.7
# 884   9/1/2021     4.6         4.6           4.5              9.2
# 885  10/1/2021     4.3         4.2           4.4              8.6
# 886  11/1/2021     3.9         3.9           3.9              9.7
#
#      unrate_18_to_19  unrate_20_to_24  unrate_25_to_34  unrate_35_to_44  \
# ...

# %%
USunemploy2 = USunemploy['date'].str.split('/', expand=True).rename(columns = lambda x: "date"+str(x+1))#add rename instead of index of 0+
USunemploy2.tail(12)
# Out:
#     date1 date2 date3
# 875    12     1  2020
# 876     1     1  2021
# 877     2     1  2021
# 878     3     1  2021
# 879     4     1  2021
# 880     5     1  2021
# 881     6     1  2021
# 882     7     1  2021
# 883     8     1  2021
# 884     9     1  2021
# 885    10     1  2021
# 886    11     1  2021

# %%
USunemploy2=pd.concat([USunemploy,USunemploy2],axis=1)

# %%
USunemploy2.groupby('date3')['unrate'].mean()#5.5 unemplyment rate for 2021
# Out:
# date3
# 1948    3.766667
# 1949    5.908333
# 1950    5.325000
# 1951    3.333333
# 1952    3.033333
#           ...
# 2017    4.350000
# 2018    3.900000
# 2019    3.666667
# 2020    8.091667
# 2021    5.518182
# Name: unrate, Length: 74, dtype: float64

# %%
USunemploy2['unrate'].mean()#mean unemployment rate for the last 73 years
# Out:
# 5.763134160090193

# %%
USunemploy2.describe()
# Out:
#            unrate  unrate_men  unrate_women  unrate_16_to_17  unrate_18_to_19  \
# count  887.000000  887.000000    887.000000       887.000000       887.000000
# mean     5.763134    5.633709      6.028749        17.943517        14.824803
# std      1.740101    1.954639      1.608252         5.018894         4.047867
# min      2.400000    1.900000      2.600000         5.700000         5.200000
# 25%      4.500000    4.300000      4.900000        14.700000        12.300000
# 50%      5.500000    5.300000      5.800000        17.800000        14.600000
# 75%      6.800000    6.700000      7.000000        20.900000        17.000000
# max     14.400000   13.300000     15.700000        35.800000        33.300000
#
#        unrate_20_to_24  unrate_25_to_34  unrate_35_to_44  unrate_45_to_54  \
# count       887.000000       887.000000       887.000000       887.000000
# mean          9.345660         5.532582         4.242954         3.867193
# ...

# %%
emcomp=pd.read_clipboard()

# %%
emcomp
# Out:
#           date  unrate  unrate_men  unrate_women  unrate_16_to_17  \
# 0     1/1/1996     6.3         6.5           6.0             21.2
# 1     2/1/1996     6.0         6.4           5.5             20.6
# 2     3/1/1996     5.8         6.3           5.3             20.5
# 3     4/1/1996     5.4         5.6           5.1             20.4
# 4     5/1/1996     5.4         5.4           5.4             20.8
# ..         ...     ...         ...           ...              ...
# 306   7/1/2021     5.7         5.5           5.8             12.8
# 307   8/1/2021     5.3         5.1           5.5             10.7
# 308   9/1/2021     4.6         4.6           4.5              9.2
# 309  10/1/2021     4.3         4.2           4.4              8.6
# 310  11/1/2021     3.9         3.9           3.9              9.7
#
#      unrate_18_to_19  unrate_20_to_24  unrate_25_to_34  unrate_35_to_44  \
# 0               17.1             11.1              6.2              4.8
# ...

# %%
emcomp.to_csv("emcomp.csv")
